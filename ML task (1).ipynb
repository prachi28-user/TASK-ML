# %%
from sklearn import preprocessing, metrics
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks", color_codes=True)
import statsmodels.api as sm
from scipy import stats

# %%
dataset = pd.read_csv("newyork2019.csv")

# %%
dataset
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 5          5099          Large Cozy 1 BR Apartment In Midtown East       7322
# 6          5121                                    BlissArtsSpace!       7356
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 9          5238                 Cute & Cozy Lower East Side 1 bdrm       7549
# 10         5295                   Beautiful 1br on Upper West Side       7702
# 11         5441                    Central Manhattan/near Broadway       7989
# 12         5803     Lovely Room 1, Garden, Best Area, Legal rental       9744
# 13         6021   Wonderful Guest Bedroom in Manhattan for SINGLES      11528
# 14         6090                      West Village Nest - Superhost      11975
# 15         6848                   Only 2 stops to Manhattan studio      15991
# 16         7097                  Perfect for Your Parents + Garden      17571
# 17         7322                                    Chelsea Perfect      18946
# 18         7726    Hip Historic Brownstone Apartment with Backyard      20950
# 19         7750                  Huge 2 BR Upper East  Cental Park      17985
# 20         7801                   Sweet and Spacious Brooklyn Loft      21207
# 21         8024                     CBG CtyBGd HelpsHaiti rm#1:1-4      22486
# 22         8025                           CBG Helps Haiti Room#2.5      22486
# 23         8110                              CBG Helps Haiti Rm #2      22486
# 24         8490             MAISON DES SIRENES1,bohemian apartment      25183
# 25         8505                 Sunny Bedroom Across Prospect Park      25326
# 26         8700  Magnifique Suite au N de Manhattan - vue Cloitres      26394
# 27         9357                               Midtown Pied-a-terre      30193
# 28         9518       SPACIOUS, LOVELY FURNISHED MANHATTAN BEDROOM      31374
# 29         9657                   Modern 1 BR / NYC / EAST VILLAGE      21904
# ...         ...                                                ...        ...
# 48865  36472171                      1 bedroom in sunlit apartment   99144947
# 48866  36472710                                 CozyHideAway Suite  274225617
# 48867  36473044    The place you were dreaming for.(only for guys)  261338177
# 48868  36473253                       Heaven for you(only for guy)  261338177
# 48869  36474023                        Cozy, Sunny Brooklyn Escape    1550580
# 48870  36474911      Cozy, clean Williamsburg 1- bedroom apartment    1273444
# 48871  36475746      A LARGE ROOM - 1 MONTH MINIMUM - WASHER&DRYER  144008701
# 48872  36476675                                      Nycity-MyHome    8636072
# 48873  36477307                                  Brooklyn paradise  241945355
# 48874  36477588                   Short Term Rental in East Harlem  214535893
# 48875  36478343                              Welcome all as family  274273284
# 48876  36478357    Cozy, Air-Conditioned Private Bedroom in Harlem  177932088
# 48877  36479230             Studio sized room with beautiful light   65767720
# 48878  36479723                                      Room for rest   41326856
# 48879  36480292  Gorgeous 1.5 Bdr with a private yard- Williams...     540335
# 48880  36481315  The Raccoon Artist Studio in Williamsburg New ...  208514239
# 48881  36481615                   Peaceful space in Greenpoint, BK  274298453
# 48871         Ozzy Ciao           Manhattan              Harlem  40.82233
# 48872               Ben           Manhattan      Hell's Kitchen  40.76236
# 48873    Clement & Rose            Brooklyn           Flatlands  40.63116
# 48874           Jeffrey           Manhattan         East Harlem  40.79760
# 48875         Anastasia           Manhattan         East Harlem  40.78749
# 48876            Joseph           Manhattan              Harlem  40.80953
# 48877           Melanie            Brooklyn            Bushwick  40.70418
# 48878       Jeerathinan              Queens            Elmhurst  40.74477
# 48879               Lee            Brooklyn        Williamsburg  40.71728
# 48880             Melki            Brooklyn        Williamsburg  40.71232
# 48881            Adrien            Brooklyn          Greenpoint  40.72585
# 48882             Luisa            Brooklyn            Bushwick  40.69652
# 48883           Kendall           Manhattan         East Harlem  40.79755
# 48884          Jonathan            Brooklyn        Williamsburg  40.71790
# 48885           Kendall           Manhattan         East Harlem  40.79633
# 48886             Scott           Manhattan             Midtown  40.75561
# 48887             Melki            Brooklyn        Williamsburg  40.71232
# 48888               Kat           Manhattan      Hell's Kitchen  40.76392
# 48889           Michael              Queens             Jamaica  40.69137
# 48890           Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891           Marisol            Brooklyn            Bushwick  40.70184
# 48892     Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893               Taz           Manhattan      Hell's Kitchen  40.75751
# 48894        Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -73.97237     Private room    149               1                  9
# 1      -73.98377  Entire home/apt    225               1                 45
# 2      -73.94190     Private room    150               3                  0
# 3      -73.95976  Entire home/apt     89               1                270
# 4      -73.94399  Entire home/apt     80              10                  9
# 5      -73.97500  Entire home/apt    200               3                 74
# 6      -73.95596     Private room     60              45                 49
# 7      -73.98493     Private room     79               2                430
# 8      -73.96723     Private room     79               2                118
# 9      -73.99037  Entire home/apt    150               1                160
# 10     -73.96545  Entire home/apt    135               5                 53
# 11     -73.98867     Private room     85               2                188
# 12     -73.98779     Private room     89               4                167
# 13     -73.96113     Private room     85               2                113
# 14     -74.00525  Entire home/apt    120              90                 27
# 15     -73.95352  Entire home/apt    140               2                148
# 16     -73.97185  Entire home/apt    215               2                198
# 17     -73.99501     Private room    140               1                260
# 18     -73.94694  Entire home/apt     99               3                 53
# 19     -73.94872  Entire home/apt    190               7                  0
# 20     -73.95718  Entire home/apt    299               3                  9
# 21     -73.97706     Private room    130               2                130
# 22     -73.97798     Private room     80               1                 39
# 23     -73.97865     Private room    110               2                 71
# 24     -73.94028  Entire home/apt    120               2                 88
# 25     -73.97519     Private room     60               1                 19
# 26     -73.92639     Private room     80               4                  0
# 27     -73.98533  Entire home/apt    150              10                 58
# 28     -73.92106     Private room     44               3                108
# 29     -73.98542  Entire home/apt    180              14                 29
# ...          ...              ...    ...             ...                ...
# 48865  -73.92449     Private room     80               1                  0
# 48866  -73.81448  Entire home/apt     58               1                  0
# 48867  -73.97116      Shared room     25               1                  0
# 48868  -73.97119      Shared room     25               7                  0
# 48869  -73.95705     Private room     45               4                  0
# 48890         NaN                NaN                               2
# 48891         NaN                NaN                               2
# 48892         NaN                NaN                               1
# 48893         NaN                NaN                               6
# 48894         NaN                NaN                               1
#
#        availability_365
# 0                   365
# 1                   355
# 2                   365
# 3                   194
# 4                     0
# 5                   129
# 6                     0
# 7                   220
# 8                     0
# 9                   188
# 10                    6
# 11                   39
# 12                  314
# 13                  333
# 14                    0
# 15                   46
# 16                  321
# 17                   12
# 18                   21
# 19                  249
# 20                    0
# 21                  347
# 22                  364
# 23                  304
# 24                  233
# 25                   85
# 26                    0
# 27                   75
# 28                  311
# 29                   67
# ...                 ...
# 48865                79
# 48866               159
# 48867               338
# 48868               365
# 48869                 7
# 48870                22
# 48871                31
# 48872                 9
# 48873               363
# 48874                22
# 48875               180
# 48876                26
# 48877                16
# 48878               172
# 48879                22
# 48880               365
# 48881                15
# 48882                31
# 48883               364
# 48884               341
# 48885               353
# 48886               176
# 48887               365
# 48888                31
# 48889               163
# 48890                 9
# 48891                36
# 48892                27
# 48893                 2
# 48894                23
#
# [48895 rows x 16 columns]

# %%
### Check data types of all columns
dataset.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %% [markdown]
# Checking null values.Since last_review and reviews per month have same null records, lets assume that that listing never got ant review

# %%
dataset.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# Let's replace reviews per month Nan by zero and null name and host_name by NoName. Also, replace last review with "Not reviewed"

# %%
dataset.fillna({'reviews_per_month':0}, inplace=True)
dataset.fillna({'name':"NoName"}, inplace=True)
dataset.fillna({'host_name':"NoName"}, inplace=True)
dataset.fillna({'last_review':"NotReviewed"}, inplace=True)

# %% [markdown]
# Time to check results

# %%
dataset.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
dataset["price"].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %% [markdown]
# We see that the average price is 152. Price varies between 0 to 10K

# %%
### See the distribution of price
hist_price=dataset["price"].hist()
### We observe that most listings have price less than $1000

# %%
### Lets plot histogram for prices less than $2000
hist_price1=dataset["price"][dataset["price"]<1000].hist()
### This give a clearer picture!

# %% [markdown]
# How many listings have price more than 1000?

# %%
dataset[dataset["price"]>1000]
# Out:
#              id                                               name    host_id  \
# 496      174966              Luxury 2Bed/2.5Bath Central Park View     836168
# 45710  NotReviewed               0.00                               3
# 45867  NotReviewed               0.00                               1
# 45891  NotReviewed               0.00                               1
# 45967   2019-06-14               2.31                               1
# 46140  NotReviewed               0.00                               1
# 46533   2019-06-24               1.00                               1
# 46614  NotReviewed               0.00                               1
# 46710  NotReviewed               0.00                               1
# 46895  NotReviewed               0.00                               1
# 47350  NotReviewed               0.00                               1
# 47391   2019-07-02               1.00                               1
# 47548  NotReviewed               0.00                               1
# 47670  NotReviewed               0.00                               7
# 47869  NotReviewed               0.00                               1
# 48043  NotReviewed               0.00                               1
# 48050  NotReviewed               0.00                               1
# 48080  NotReviewed               0.00                               1
# 48304  NotReviewed               0.00                               1
# 48305  NotReviewed               0.00                               1
# 48523  NotReviewed               0.00                               1
# 48535  NotReviewed               0.00                               1
#
#        availability_365
# 496                   0
# 762                 297
# 946                 365
# 1105                  0
# 1480                364
# 1862                 83
# 2018                 89
# 2236                362
# 2520                  0
# 2523                  0
# 2698                365
# 2772                364
# 2896                  0
# 3131                  0
# 3306                  0
# 3333                  0
# 3537                359
# 3598                  0
# 3622                  0
# 3637                  0
# 3684                  0
# 3695                  0
# 3702                  0
# 3720                  0
# 3721                  0
# 3723                  0
# 3731                  0
# 3732                  0
# 3758                  0
# 3761                260
# ...                 ...
# 43009               343
# 43563               270
# 43670               347
# 44034               364
# 44429                 0
# 45185               168
# 45414               332
# 45572                23
# 45666               179
# 45710               191
# 45867                90
# 45891               335
# 45967               193
# 46140               179
# 46533               214
# 46614               365
# 46710                51
# 46895               178
# 47350               365
# 47391                17
# 47548               270
# 47670               267
# 47869               365
# 48043               365
# 48050               365
# 48080               179
# 48304               222
# 48305               270
# 48523               349
# 48535               303
#
# [239 rows x 16 columns]

# %% [markdown]
# 239 listings have price per day > 1000. These are either super lavish listings or there was an error during input. Nonetheless, since this records are skewing our data a lot, we will treat them as outliers and drop them.

# %%
dataset=dataset[dataset["price"]<1000]

# %%
### We see a more Gaussian distribution here
hist_price2=dataset["price"][dataset["price"]<250].hist()

# %%
### We use 250 as threshold price 
dataset=dataset[dataset["price"]<250]

# %%
### Looking at the price column again
dataset["price"].describe()
# Out:
# count    42669.000000
# mean       107.897748
# std         53.803457
# min          0.000000
# 25%         65.000000
# 50%         99.000000
# 75%        150.000000
# max        249.000000
# Name: price, dtype: float64

# %% [markdown]
# We see that the average price is 107. Price varies between 0 to 249

# %%
###There are 221 unique neighbourhoods in NYC as per this data set. Most listings are in Williamsburg
dataset['neighbourhood'].value_counts()
# Out:
# Bedford-Stuyvesant            3560
# Williamsburg                  3451
# Harlem                        2487
# Bushwick                      2404
# Upper West Side               1570
# Upper East Side               1515
# East Village                  1503
# Hell's Kitchen                1501
# Crown Heights                 1462
# East Harlem                   1031
# Greenpoint                    1018
# Midtown                        920
# Washington Heights             870
# Astoria                        861
# Lower East Side                768
# Chelsea                        759
# Flatbush                       600
# Financial District             562
# Prospect-Lefferts Gardens      515
# Clinton Hill                   509
# West Village                   501
# Long Island City               494
# East Flatbush                  485
# Fort Greene                    434
# Park Slope                     428
# Ridgewood                      417
# Flushing                       409
# Kips Bay                       371
# Sunset Park                    364
# Murray Hill                    359
#                               ...
# Bay Terrace                      5
# Sea Gate                         5
# Tottenville                      5
# Little Neck                      5
# New Dorp Beach                   5
# New Brighton                     5
# Holliswood                       4
# Olinville                        4
# Arden Heights                    4
# Graniteville                     3
# Prince's Bay                     3
# Spuyten Duyvil                   3
# Castleton Corners                3
# Huguenot                         3
# Todt Hill                        3
# Lighthouse Hill                  2
# West Farms                       2
# Mill Basin                       2
# Co-op City                       2
# Bay Terrace, Staten Island       2
# Howland Hook                     2
# Silver Lake                      2
# Breezy Point                     2
# Eltingville                      2
# Westerleigh                      2
# Neponsit                         1
# Richmondtown                     1
# New Dorp                         1
# Willowbrook                      1
# Rossville                        1
# Name: neighbourhood, Length: 219, dtype: int64

# %%
### Count how many neighbourhoods appear more than 200
dfnh =dataset.groupby("neighbourhood").filter(lambda x: x['neighbourhood'].count() > 200)

# %%
### Most data is covered. 
len(dfnh["neighbourhood"])
# Out:
# 36106

# %%
### Count how many neighbourhoods appear only once
dfnh =dataset.groupby("neighbourhood").filter(lambda x: x['neighbourhood'].count() == 1)
len(dfnh["neighbourhood"])
# Out:
# 5

# %%
###Lets look at neighbourhood groups
dataset['neighbourhood_group'].value_counts()
# Out:
# Brooklyn         18581
# Manhattan        17270
# Queens            5413
# Bronx             1052
# Staten Island      353
# Name: neighbourhood_group, dtype: int64

# %% [markdown]
# There are five major neighbourhood groups in NYC with Manhattan and Brooklyn accounting for 85% of the listings

# %%
### Lets see the average listing price by neighbourhood group
ng_price=dataset.groupby("neighbourhood_group")["price"].mean()

# %%
### Manhattan is most expensive and Bronx is the least expensive place to live
ng_price
# Out:
# neighbourhood_group
# Bronx             73.796578
# Brooklyn          98.068134
# Manhattan        128.670990
# Queens            83.639941
# Staten Island     82.606232
# Name: price, dtype: float64

# %% [markdown]
# Here we can note that Brooklyn and Manhattan tend to have more listings with price>150. We also note thar most listings above price>100 are entire home type followed by private room and shared room which is the cheapest.

# %%
### Checking if there are duplicate host_ids and whats is the maximum number of listings per host_id
df = dataset.groupby(["host_id"])
max(df.size())
# Out:
# 238L

# %%
## Here we can see that 32K host_ids are unique appearing only once whereas some host_ids appear as much as 238 times
df.size().value_counts().head()
# Out:
# 1    28391
# 2     2993
# 3      844
# 4      302
# 5      151
# dtype: int64

# %%
df.size().value_counts().tail()
# Out:
# 45     1
# 30     1
# 238    1
# 16     1
# 87     1
# dtype: int64

# %%
### Finding the host_id with maximum listings
host_id_counts = dataset["host_id"].value_counts()
max_host = host_id_counts.idxmax()
max_host
# Out:
# 219517861

# %%
###We see that Sonder(NYC) has the max number of listings
dataset[dataset["host_id"]==219517861]
# Out:
#              id                                               name    host_id  \
# 38294  30181945         Sonder | 180 Water | Premier 1BR + Rooftop  219517861
# 38588  30347708        Sonder | 180 Water | Charming 1BR + Rooftop  219517861
# 41374   2019-06-04               1.46                             327
# 41376   2019-06-24               1.52                             327
# 41383   2019-05-13               1.69                             327
# 41384   2019-06-18               1.85                             327
# 41385   2019-06-20               1.98                             327
# 41386   2019-05-17               1.75                             327
# 41387   2019-06-16               1.49                             327
# 41404   2019-06-24               1.88                             327
# 41405   2019-05-28               2.13                             327
# 41407   2019-06-23               3.65                             327
# 41408   2019-06-16               3.05                             327
# 41410   2019-05-18               0.73                             327
# 41413   2019-05-26               1.69                             327
# 41417   2019-06-13               2.34                             327
# ...            ...                ...                             ...
# 45722  NotReviewed               0.00                             327
# 45723  NotReviewed               0.00                             327
# 45725  NotReviewed               0.00                             327
# 45728  NotReviewed               0.00                             327
# 45731  NotReviewed               0.00                             327
# 45932  NotReviewed               0.00                             327
# 45933  NotReviewed               0.00                             327
# 45934  NotReviewed               0.00                             327
# 45937  NotReviewed               0.00                             327
# 45938  NotReviewed               0.00                             327
# 45939  NotReviewed               0.00                             327
# 45946  NotReviewed               0.00                             327
# 45947  NotReviewed               0.00                             327
# 45948  NotReviewed               0.00                             327
# 45949  NotReviewed               0.00                             327
# 45950  NotReviewed               0.00                             327
# 45951  NotReviewed               0.00                             327
# 45953  NotReviewed               0.00                             327
# 45955  NotReviewed               0.00                             327
# 45958  NotReviewed               0.00                             327
# 45959  NotReviewed               0.00                             327
# 46021  NotReviewed               0.00                             327
# 46214  NotReviewed               0.00                             327
# 46215  NotReviewed               0.00                             327
# 47528  NotReviewed               0.00                             327
# 47686  NotReviewed               0.00                             327
# 47687  NotReviewed               0.00                             327
# 47691  NotReviewed               0.00                             327
# 47692  NotReviewed               0.00                             327
# 47693  NotReviewed               0.00                             327
#
#        availability_365
# 38294               219
# 38588               159
# 39771               137
# 39772               281
# 39773               332
# 39775               325
# 39776               111
# 39777                99
# 39778               130
# 39781               153
# 40476               334
# 41362               272
# 41363               299
# 41364               352
# 41365               355
# 41366               327
# 41374               332
# 41376               306
# 41383               347
# 41384               341
# 41385               357
# 41386               346
# 41387               346
# 41404               338
# 41405               263
# 41407               323
# 41408               340
# 41410               350
# 41413               337
# 41417               349
# ...                 ...
# 45722               361
# 45723               333
# 45725               341
# 45728               345
# 45731               318
# 45932               326
# 45933               347
# 45934               333
# 45937               302
# 45938               332
# 45939                37
# 45946               343
# 45947               354
# 45948               336
# 45949               311
# 45950               335
# 45951               329
# 45953               360
# 45955               365
# 45958               341
# 45959               357
# 46021               347
# 46214               344
# 46215               354
# 47528               342
# 47686               345
# 47687               338
# 47691               339
# 47692               342
# 47693               347
#
# [238 rows x 16 columns]

# %% [markdown]
# Listing id and Host name are not useful for our analysis so I will drop them

# %%
dataset = dataset.drop(columns = ["id","host_name"])

# %%
### Let's Analyse the listing name column
dataset["name_length"]=dataset['name'].map(str).apply(len)

# %%
###Max and Min name length
print(dataset["name_length"].max())
print(dataset["name_length"].min())
print(dataset["name_length"].idxmax())
print(dataset["name_length"].idxmin())
# Out:
# 179
# 1
# 25832
# 4033

# %%
### Max name 
dataset.at[25832, 'name']
# Out:
# 'The printing studio bedroom with garden in Bedstuy  !!Brooklyn. Historic neighborhood close to everything ! Full kitchen bathroom BBQ and porch at your disposal. Learn to print !!'

# %%
###Min name
dataset.at[4033, 'name']
# Out:
# '/'

# %%
### Let's figure if name length has an impact on how much it is noticed. We can assume higher number of reviews mean more people lived there and hence more people "noticed" the listing
#dataset["name_length"].corr(dataset["number_of_reviews"])
dataset.plot.scatter(x="name_length", y ="number_of_reviews" )

# %%
###There is hardly any relationship there. Lets try between price and name length 
dataset[dataset["name_length"]<50].plot.scatter(x="price", y ="name_length")
#dataset["name_length"].corr(dataset["price"])

# %%
dataset.name_length.hist()

# %%
### Lets look at room_type variable
dataset['room_type'].value_counts()
### Most listings are either Entire home or Private room
# Out:
# Private room       21753
# Entire home/apt    19790
# Shared room         1126
# Name: room_type, dtype: int64

# %%
### Average price per room_type
rt_price = dataset.groupby("room_type")["price"].mean()

# %%
### Entire room has the highest price and shared room has lowest avg price which makes sense.
rt_price
# Out:
# room_type
# Entire home/apt    144.977211
# Private room        76.802832
# Shared room         56.925400
# Name: price, dtype: float64

# %%
### Analysing minimum nights

dataset["minimum_nights"].describe()
# Out:
# count    42669.000000
# mean         6.856359
# std         19.981924
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max       1250.000000
# Name: minimum_nights, dtype: float64

# %%
### Analysing minimum nights
### We see most values are between 1 to 100
hist_mn=dataset["minimum_nights"].hist()
hist_mn

# %%
### Closer look
hist_mn1=dataset["minimum_nights"][dataset["minimum_nights"]<10].hist()
hist_mn1

# %%
dataset["minimum_nights"][dataset["minimum_nights"]>30]
# Out:
# 6         45
# 14        90
# 36        60
# 81        31
# 106       90
# 155       45
# 245      200
# 247       50
# 336       35
# 349       90
# 441       40
# 446       31
# 457       40
# 469       44
# 481       65
# 566       90
# 655       60
# 667      120
# 694       90
# 700      365
# 712       31
# 719      180
# 724       90
# 754      365
# 757      122
# 769      180
# 823       60
# 970      240
# 1038     180
# 1045      88
#         ...
# 45705     31
# 45744     31
# 45852     31
# 45861     33
# 45926     70
# 46072     31
# 46082     70
# 46192     60
# 46302     31
# 46362     31
# 46470     91
# 46661     31
# 47098     31
# 47101     31
# 47262     31
# 47506     31
# 47620    500
# 47745    120
# 47808     31
# 47875     31
# 47931     31
# 47973     90
# 48010     31
# 48145     90
# 48205    180
# 48312     90
# 48325     60
# 48368     60
# 48446    365
# 48752     32
# Name: minimum_nights, Length: 628, dtype: int64

# %%
### We replace all records with min nights > 30 by 30
dataset.loc[(dataset.minimum_nights >30),"minimum_nights"]=30

# %%
hist_mn2=dataset["minimum_nights"][dataset["minimum_nights"]<30].hist()
hist_mn2

# %%
### Does minimum_nights have impact on price?
dataset["minimum_nights"].corr(dataset["price"])
# Out:
# 0.05955436171912607

# %%
###Finally lets analyse availability_365 column
dataset["availability_365"].describe()
# Out:
# count    42669.000000
# mean       107.622747
# std        129.731981
# min          0.000000
# 25%          0.000000
# 50%         37.000000
# 75%        211.000000
# max        365.000000
# Name: availability_365, dtype: float64

# %%
hist_av=dataset["availability_365"].hist()
hist_av

# %%
### After analysis, I have decided to drop these columns as they will not be useful in prediction
dataset.drop(["name",'last_review',"latitude",'longitude'], axis=1, inplace=True)

# %%
### Dropping host_id
dataset.drop(["host_id"], axis=1, inplace=True)

# %%
### Plotting correlation matrix 
corr = dataset.corr(method='pearson')
plt.figure(figsize=(15,8))
sns.heatmap(corr, annot=True)
dataset.columns
# Out:
# Index([u'neighbourhood_group', u'neighbourhood', u'room_type', u'price',
#        u'minimum_nights', u'number_of_reviews', u'reviews_per_month',
#        u'calculated_host_listings_count', u'availability_365', u'name_length'],
#       dtype='object')

# %%
### Lets check out data one more time before beginning prediction. 
###Looks good!
dataset.dtypes
# Out:
# neighbourhood_group                object
# neighbourhood                      object
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# name_length                         int64
# dtype: object

# %% [markdown]
# # Let us start with basic Linear Regression to create a base line model

# %% [markdown]
# Making dummies for neighbourhood group and room_type

# %%
## lets try without neighbourhood column

dataset_onehot1 = pd.get_dummies(dataset, columns=['neighbourhood_group',"room_type"], prefix = ['ng',"rt"],drop_first=True)
dataset_onehot1.drop(["neighbourhood"], axis=1, inplace=True)

# %%
### Checking dataframe shape
dataset_onehot1.shape
# Out:
# (42669, 13)

# %%
X1= dataset_onehot1.loc[:, dataset_onehot1.columns != 'price']

# %%
Y1 = dataset_onehot1["price"]

# %% [markdown]
# # Splitting into training and testing data

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(X1, Y1, test_size=0.20, random_state=42)

# %%
### Fitting Linear regression
reg1 = LinearRegression().fit(x_train1, y_train1)

# %%
### R squared value
reg1.score(x_train1, y_train1)
# Out:
# 0.5032644651024666

# %%
### Coefficients
reg1.coef_
# Out:
# array([-8.09295059e-01, -9.22797543e-03, -1.61121210e+00,  1.42694125e-01,
#         4.67768190e-02,  1.90705709e-01,  1.98316084e+01,  4.41878714e+01,
#         9.59692984e+00,  2.47220418e-01, -6.56745710e+01, -8.91235603e+01])

# %%
### Predicting 
y_pred1 = reg1.predict(x_test1)

# %%
Coeff1 = pd.DataFrame(columns=["Variable","Coefficient"])
Coeff1["Variable"]=x_train1.columns
Coeff1["Coefficient"]=reg1.coef_
Coeff1.sort_values("Coefficient")
# Out:
#                           Variable  Coefficient
# 11                  rt_Shared room   -89.123560
# 10                 rt_Private room   -65.674571
# 2                reviews_per_month    -1.611212
# 0                   minimum_nights    -0.809295
# 1                number_of_reviews    -0.009228
# 4                 availability_365     0.046777
# 3   calculated_host_listings_count     0.142694
# 5                      name_length     0.190706
# 9                 ng_Staten Island     0.247220
# 8                        ng_Queens     9.596930
# 6                      ng_Brooklyn    19.831608
# 7                     ng_Manhattan    44.187871

# %%
### Calculate RMSE
rmse1 = np.sqrt(metrics.mean_squared_error(y_test1, y_pred1))
rmse1
# Out:
# 37.688831948199386

# %%
### Taking a closer look at the estimates
X2 = sm.add_constant(x_train1)
est = sm.OLS(y_train1, X2)
est2 = est.fit()
print(est2.summary())
# Out:
# C:\Users\kunal\Anaconda2\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.503
# Model:                            OLS   Adj. R-squared:                  0.503
# Method:                 Least Squares   F-statistic:                     2881.
# Date:                Wed, 22 Jul 2020   Prob (F-statistic):               0.00
# Time:                        12:56:54   Log-Likelihood:            -1.7259e+05
# No. Observations:               34135   AIC:                         3.452e+05
# Df Residuals:                   34122   BIC:                         3.453e+05
# Df Model:                          12
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                            109.8817      1.521     72.228      0.000     106.900     112.864
# minimum_nights                    -0.8093      0.027    -30.097      0.000      -0.862      -0.757
# number_of_reviews                 -0.0092      0.006     -1.632      0.103      -0.020       0.002
# reviews_per_month                 -1.6112      0.163     -9.874      0.000      -1.931      -1.291
# calculated_host_listings_count     0.1427      0.008     18.116      0.000       0.127       0.158
# availability_365                   0.0468      0.002     26.677      0.000       0.043       0.050
# name_length                        0.1907      0.020      9.632      0.000       0.152       0.230
# ng_Brooklyn                       19.8316      1.349     14.700      0.000      17.187      22.476
# ng_Manhattan                      44.1879      1.356     32.587      0.000      41.530      46.846
# ng_Queens                          9.5969      1.428      6.719      0.000       6.797      12.396
# ng_Staten Island                   0.2472      2.583      0.096      0.924      -4.816       5.310
# rt_Private room                  -65.6746      0.427   -153.922      0.000     -66.511     -64.838
# rt_Shared room                   -89.1236      1.315    -67.785      0.000     -91.701     -86.547
# ==============================================================================
# Omnibus:                     2347.846   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3131.000
# Skew:                           0.617   Prob(JB):                         0.00
# Kurtosis:                       3.824   Cond. No.                     2.69e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.69e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
## No of reviews and ng_Staten Island is not significant and does not help our model much. Drop it
x_train1.drop(["number_of_reviews","ng_Staten Island"], axis=1,inplace=True)
X2 = sm.add_constant(x_train1)
est = sm.OLS(y_train1, X2)
est2 = est.fit()
print(est2.summary())
### Does not improve our model much
# Out:
# C:\Users\kunal\Anaconda2\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.503
# Model:                            OLS   Adj. R-squared:                  0.503
# Method:                 Least Squares   F-statistic:                     3457.
# Date:                Wed, 22 Jul 2020   Prob (F-statistic):               0.00
# Time:                        12:56:56   Log-Likelihood:            -1.7259e+05
# No. Observations:               34135   AIC:                         3.452e+05
# Df Residuals:                   34124   BIC:                         3.453e+05
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                            109.8869      1.376     79.840      0.000     107.189     112.585
# minimum_nights                    -0.8072      0.027    -30.054      0.000      -0.860      -0.755
# reviews_per_month                 -1.7613      0.135    -13.064      0.000      -2.026      -1.497
# calculated_host_listings_count     0.1435      0.008     18.265      0.000       0.128       0.159
# availability_365                   0.0464      0.002     26.725      0.000       0.043       0.050
# name_length                        0.1928      0.020      9.762      0.000       0.154       0.232
# ng_Brooklyn                       19.6900      1.177     16.730      0.000      17.383      21.997
# ng_Manhattan                      44.0490      1.185     37.178      0.000      41.727      46.371
# ng_Queens                          9.5165      1.267      7.509      0.000       7.033      12.001
# rt_Private room                  -65.6519      0.426   -153.980      0.000     -66.488     -64.816
# rt_Shared room                   -89.0249      1.313    -67.802      0.000     -91.598     -86.451
# ==============================================================================
# Omnibus:                     2355.682   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3144.617
# Skew:                           0.618   Prob(JB):                         0.00
# Kurtosis:                       3.827   Cond. No.                     1.93e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.93e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Lets try to use the neighbourhood variable. It has more than 200 distinct values.

# %% [markdown]
#  # Hence, when we create dummies we will have large number of variables

# %%
dataset_onehot2 = pd.get_dummies(dataset, columns=['neighbourhood_group',"neighbourhood","room_type"], prefix = ['ng',"nh","rt"],drop_first=True)

# %%
dataset_onehot2.shape
# Out:
# (42669, 231)

# %%
XL1= dataset_onehot2.loc[:, dataset_onehot2.columns != 'price']
YL1 = dataset_onehot2["price"]
x_trainL11, x_testL11, y_trainL11, y_testL11 = train_test_split(XL1, YL1, test_size=0.20, random_state=42)

# %% [markdown]
# We will use Lasso regression because it has the ability to nullify parameters that do not improve the model. Also, the dataset isn't large enough and hence Lasso is a good choice as it would add a little bit bias but reduce variance greatly. Starting with alpha=0.1 We can use crossvalidation and check for many values for alpha to find best one, but I will save this process for the next model which I think will procduce better results.

# %%
regL1 = Lasso(alpha=0.01)
regL1.fit(x_trainL11, y_trainL11)
# Out:
# Lasso(alpha=0.01, copy_X=True, fit_intercept=True, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=False)

# %%
### R squared
### This regularised model did way better than normal linear regression
regL1.score(x_trainL11, y_trainL11)
# Out:
# 0.5672418427326821

# %%
### RMSE
### Smaller value than earlier
y_predL1= regL1.predict(x_testL11)
print(np.sqrt(metrics.mean_squared_error(y_testL11,y_predL1)))
# Out:
# 35.12349961863741

# %%
### We can see that some parameters have zero coefficients.
regL1.coef_
# Out:
# array([-8.74190014e-01, -1.55670709e-02, -1.21425391e+00,  8.54911005e-02,
#         5.35976416e-02,  1.27709939e-01,  1.25999750e+01,  5.02392738e+01,
#         6.26797494e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00,  7.69762437e+00, -0.00000000e+00,  0.00000000e+00,
#        -5.75232835e-01,  0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00,  6.08515566e-01,  0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00, -9.24884791e+00, -0.00000000e+00,
#         2.15168267e+01, -1.25480375e+01,  0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -3.47487282e+00,  2.93983017e+01, -4.41250213e+00,
#         0.00000000e+00, -1.33945125e+00,  0.00000000e+00, -7.57389675e+00,
#         2.39917308e+01, -0.00000000e+00,  0.00000000e+00,  1.25460918e+01,
#        -6.68685679e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00,  1.78034051e+01,  0.00000000e+00,
#         2.19968884e+01, -0.00000000e+00,  2.39437116e+00, -0.00000000e+00,
#         0.00000000e+00,  0.00000000e+00, -0.00000000e+00, -1.00377390e+01,
#         0.00000000e+00, -9.41569836e+00,  3.24213250e+01,  4.23510592e+00,
#        -0.00000000e+00, -0.00000000e+00,  2.54310580e+01, -0.00000000e+00,
#        -0.00000000e+00, -6.36694495e+00, -1.93912443e+01, -0.00000000e+00,
#        -1.06992738e+01, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00,  1.25511214e+01, -9.73514966e+00,
#         8.44161017e+00, -0.00000000e+00,  1.29360931e+00,  0.00000000e+00,
#         0.00000000e+00,  2.42939513e+01,  0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00,  2.10703967e+01,  3.26472315e+00, -0.00000000e+00,
#        -0.00000000e+00, -1.68630731e+00,  0.00000000e+00,  2.09571419e+01,
#         1.62703682e+01,  0.00000000e+00, -2.66523767e+01,  1.07163761e+01,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -4.02167387e+01,
#         0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#        -7.58489527e+00,  0.00000000e+00, -0.00000000e+00,  0.00000000e+00,
#        -1.10007770e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00,  1.76566720e+01,  0.00000000e+00, -2.72160092e+00,
#        -0.00000000e+00, -1.68818648e+01,  0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,  1.19434818e+01,
#        -8.79700515e+00, -0.00000000e+00, -2.15207706e+01,  0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00,  9.86300253e+00,  1.14017982e+01,  0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#         0.00000000e+00,  6.14718733e+00,  0.00000000e+00,  0.00000000e+00,
#        -0.00000000e+00,  0.00000000e+00, -2.82687269e+00,  2.40327413e+01,
#        -0.00000000e+00,  0.00000000e+00, -4.01997448e+00,  4.30767557e+00,
#         0.00000000e+00,  0.00000000e+00,  1.57501375e+01, -2.60101352e+00,
#        -7.26517162e+00, -0.00000000e+00,  1.68802886e-01, -7.07259849e+00,
#        -0.00000000e+00, -0.00000000e+00, -4.50249870e-01,  0.00000000e+00,
#         3.70022784e+00, -1.67103079e+01,  0.00000000e+00, -2.27854901e+00,
#         0.00000000e+00,  0.00000000e+00,  0.00000000e+00, -5.58509956e+00,
#         0.00000000e+00, -0.00000000e+00,  1.42719193e+01, -0.00000000e+00,
#         0.00000000e+00, -0.00000000e+00,  1.88711491e+01,  2.45527301e+00,
#        -0.00000000e+00, -6.10267883e+00,  0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00,  5.50980139e-01, -2.52983783e+00,  1.19256526e+01,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00,  2.12461464e+01, -2.00007599e+00, -0.00000000e+00,
#         0.00000000e+00, -4.46189015e+00, -2.68448817e+00, -0.00000000e+00,
#         3.24889470e+01, -0.00000000e+00, -3.88638973e+01, -0.00000000e+00,
#         0.00000000e+00,  1.89930123e+01, -0.00000000e+00, -0.00000000e+00,
#        -0.00000000e+00, -0.00000000e+00,  2.28045218e+01,  0.00000000e+00,
#         3.24391413e+00, -6.34892882e+00, -0.00000000e+00,  1.98903040e+00,
#        -6.17060202e+01, -8.46050450e+01])

# %%
CoeffLS1 = pd.DataFrame(columns=["Variable","Coefficients"])
CoeffLS1["Variable"]=x_trainL11.columns
CoeffLS1["Coefficients"]=regL1.coef_
CoeffLS1.sort_values("Coefficients", ascending = False)
# Out:
#                    Variable  Coefficients
# 7              ng_Manhattan     50.239274
# 212         nh_Vinegar Hill     32.488947
# 62                 nh_DUMBO     32.421325
# 34      nh_Brooklyn Heights     29.398302
# 66     nh_Downtown Brooklyn     25.431058
# 89           nh_Fort Greene     24.293951
# 159           nh_Park Slope     24.032741
# 40       nh_Carroll Gardens     23.991731
# 222         nh_Williamsburg     22.804522
# 52           nh_Cobble Hill     21.996888
# 28           nh_Boerum Hill     21.516827
# 205              nh_Tribeca     21.246146
# 93               nh_Gowanus     21.070397
# 99            nh_Greenpoint     20.957142
# 217         nh_West Village     18.993012
# 190          nh_South Slope     18.871149
# 50          nh_Clinton Hill     17.803405
# 125     nh_Long Island City     17.656672
# 100    nh_Greenwich Village     16.270368
# 166     nh_Prospect Heights     15.750138
# 186                 nh_SoHo     14.271919
# 6               ng_Brooklyn     12.599975
# 82    nh_Financial District     12.551121
# 43               nh_Chelsea     12.546092
# 135              nh_Midtown     11.943482
# 199     nh_Theater District     11.925653
# 146            nh_Navy Yard     11.401798
# 103       nh_Hell's Kitchen     10.716376
# 145          nh_Murray Hill      9.863003
# 84     nh_Flatiron District      8.441610
# ..                      ...           ...
# 158           nh_Ozone Park     -2.826873
# 33             nh_Bronxdale     -3.474873
# 162       nh_Pelham Gardens     -4.019974
# 35           nh_Brownsville     -4.412502
# 209      nh_Upper East Side     -4.461890
# 183       nh_Sheepshead Bay     -5.585100
# 193           nh_St. Albans     -6.102679
# 225            nh_Woodhaven     -6.348929
# 69         nh_East Flatbush     -6.366945
# 44             nh_Chinatown     -6.686857
# 171            nh_Rego Park     -7.072598
# 168       nh_Queens Village     -7.265172
# 39              nh_Canarsie     -7.573897
# 116           nh_Kensington     -7.584895
# 136              nh_Midwood     -8.797005
# 26           nh_Bensonhurst     -9.248848
# 61         nh_Cypress Hills     -9.415698
# 83              nh_Flatbush     -9.735150
# 59                nh_Corona    -10.037739
# 72         nh_East New York    -10.699274
# 29          nh_Borough Park    -12.548038
# 177     nh_Roosevelt Island    -16.710308
# 129          nh_Marble Hill    -16.881865
# 70           nh_East Harlem    -19.391244
# 138  nh_Morningside Heights    -21.520771
# 102               nh_Harlem    -26.652377
# 214   nh_Washington Heights    -38.863897
# 111               nh_Inwood    -40.216739
# 228         rt_Private room    -61.706020
# 229          rt_Shared room    -84.605045
#
# [230 rows x 2 columns]

# %%
### Finally, lets try Random forest regressor which I believe will give best results

# %%
### Initially, lets build a tree without any constraints.
regrRM = RandomForestRegressor(n_estimators=300)
regrRM.fit(x_trainL11, y_trainL11)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=300, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
### We get R squared value at 93.6%! There is obviously a problem of overfitting:(

print(regrRM.score(x_trainL11, y_trainL11))
y_predL1= regrRM.predict(x_testL11)
print(np.sqrt(metrics.mean_squared_error(y_testL11,y_predL1)))
# Out:
# 0.9359660173276375
# 34.905042798029136

# %%
### Using feature importance, we can see which feature had most weight
regrRM.feature_importances_
# Out:
# array([5.17691245e-02, 5.81153569e-02, 7.66781307e-02, 3.76730513e-02,
#        7.32860554e-02, 8.50688936e-02, 3.82163705e-03, 6.09061062e-02,
#        1.28863666e-03, 2.69508016e-04, 5.77748112e-07, 1.10528590e-04,
#        2.76483389e-04, 1.25201823e-03, 2.22511961e-05, 2.17446691e-04,
#        6.24097202e-04, 4.18541667e-05, 1.85560210e-05, 3.28957909e-06,
#        2.08664633e-04, 7.27263101e-05, 2.99570980e-03, 3.97680088e-04,
#        3.94056896e-05, 2.22118688e-04, 2.41977942e-04, 1.38434533e-04,
#        7.75596412e-04, 3.02001158e-04, 1.43302770e-04, 3.17943777e-04,
#        2.86314233e-04, 1.74342113e-05, 1.48783813e-03, 1.50170326e-04,
#        6.59713496e-06, 2.36870750e-03, 9.12134902e-05, 3.91055945e-04,
#        1.41796144e-03, 1.69571242e-05, 6.84952681e-05, 2.58080877e-03,
#        9.40866195e-04, 4.77240108e-05, 2.32896452e-04, 1.04647117e-04,
#        1.14110747e-05, 1.44674028e-04, 1.91116256e-03, 9.59989810e-07,
#        4.95062379e-04, 5.54034919e-05, 2.70523514e-04, 1.03196386e-04,
#        1.70690890e-04, 5.70706538e-05, 4.48316056e-05, 4.94661567e-05,
#        2.25624470e-03, 3.81533176e-04, 6.38937440e-04, 9.02362438e-04,
#        2.18794809e-05, 2.66844711e-03, 2.58462293e-03, 2.21895089e-05,
#        6.81955217e-04, 1.71622613e-04, 9.91313872e-03, 1.88101627e-05,
#        0.00000000e+00, 1.51634686e-03, 1.26339768e-05, 4.66122787e-07,
#        2.73506869e-05, 5.91951183e-05, 1.04057058e-02, 9.92311381e-05,
#        5.97100680e-04, 1.63936602e-04, 2.54457749e-05, 4.00245381e-04,
#        3.48751576e-01, 6.66765851e-02])

# %%
CoeffRM1 = pd.DataFrame(columns=["Variable","FeatureImportance"])
CoeffRM1["Variable"]=x_trainL11.columns
CoeffRM1["FeatureImportance"]=regrRM.feature_importances_
CoeffRM1.sort_values("FeatureImportance", ascending = False)
# Out:
#                            Variable  FeatureImportance
# 228                 rt_Private room       3.487516e-01
# 5                       name_length       8.506889e-02
# 2                 reviews_per_month       7.667813e-02
# 4                  availability_365       7.328606e-02
# 229                  rt_Shared room       6.667659e-02
# 7                      ng_Manhattan       6.090611e-02
# 1                 number_of_reviews       5.811536e-02
# 0                    minimum_nights       5.176912e-02
# 3    calculated_host_listings_count       3.767305e-02
# 222                 nh_Williamsburg       1.040571e-02
# 214           nh_Washington Heights       9.913139e-03
# 102                       nh_Harlem       9.871414e-03
# 70                   nh_East Harlem       4.650374e-03
# 111                       nh_Inwood       4.047432e-03
# 6                       ng_Brooklyn       3.821637e-03
# 103               nh_Hell's Kitchen       3.334626e-03
# 99                    nh_Greenpoint       3.126471e-03
# 22            nh_Bedford-Stuyvesant       2.995710e-03
# 209              nh_Upper East Side       2.668447e-03
# 210              nh_Upper West Side       2.584623e-03
# 43                       nh_Chelsea       2.580809e-03
# 37                      nh_Bushwick       2.368708e-03
# 135                      nh_Midtown       2.364238e-03
# 89                   nh_Fort Greene       2.279643e-03
# 60                 nh_Crown Heights       2.256245e-03
# 73                  nh_East Village       2.142277e-03
# 83                      nh_Flatbush       2.135309e-03
# 82            nh_Financial District       2.077188e-03
# 159                   nh_Park Slope       2.055331e-03
# 138          nh_Morningside Heights       1.995716e-03
# ..                              ...                ...
# 106                   nh_Holliswood       1.299866e-05
# 134                nh_Midland Beach       1.286584e-05
# 218           nh_Westchester Square       1.263398e-05
# 74                   nh_Eastchester       1.163268e-05
# 48                  nh_Clason Point       1.141107e-05
# 95                  nh_Graniteville       1.129812e-05
# 96                    nh_Grant City       1.087908e-05
# 65                    nh_Douglaston       1.054055e-05
# 203                  nh_Tottenville       1.029708e-05
# 149                     nh_New Dorp       8.219756e-06
# 36                   nh_Bull's Head       6.597135e-06
# 115                nh_Jamaica Hills       6.267049e-06
# 201                    nh_Todt Hill       4.812106e-06
# 192               nh_Spuyten Duyvil       3.803028e-06
# 79                  nh_Emerson Hill       3.636663e-06
# 207                    nh_Unionport       3.630540e-06
# 19                    nh_Baychester       3.289579e-06
# 150               nh_New Dorp Beach       2.690451e-06
# 156                      nh_Oakwood       2.050898e-06
# 108                 nh_Howland Hook       1.421186e-06
# 124                  nh_Little Neck       1.005344e-06
# 51                    nh_Co-op City       9.599898e-07
# 109                     nh_Huguenot       8.010679e-07
# 10                 nh_Arden Heights       5.777481e-07
# 185                  nh_Silver Lake       5.324787e-07
# 219                  nh_Westerleigh       4.661228e-07
# 78                   nh_Eltingville       2.767172e-07
# 173                 nh_Richmondtown       2.197717e-07
# 216                   nh_West Farms       0.000000e+00
# 180                    nh_Rossville       0.000000e+00
#
# [230 rows x 2 columns]

# %%
regrRM.get_params()
# Out:
# {'bootstrap': True,
#  'criterion': 'mse',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 300,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# Lets see what we can do to prevent overfitting
# We will set max depth to 50. This ensures that branching stops after 50th branching, otherwise each sample may have its branch and overfit.
# We will use min_samples_split as 5. The default value is 2. This means that each internal node will split as long as it has a minimum of two sample. We dont want that!
# We will use min_samples_leaf as 4. The default is 1. This means that a node is considered leaf node if it has just one sample. This can cause severe overfitting!

# %%
regrRM2 = RandomForestRegressor(n_estimators=200, max_depth = 50, min_samples_split = 5,min_samples_leaf =4)
regrRM2.fit(x_trainL11, y_trainL11)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=50,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=4, min_samples_split=5,
#            min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
### We get a smaller value for R squared
print(regrRM2.score(x_trainL11, y_trainL11))
y_predL1= regrRM2.predict(x_testL11)
print(np.sqrt(metrics.mean_squared_error(y_testL11,y_predL1)))
# Out:
# 0.7975698859806486
# 34.362786495663315

# %%
CoeffRM2 = pd.DataFrame(columns=["Variable","FeatureImportance"])
CoeffRM2["Variable"]=x_trainL11.columns
CoeffRM2["FeatureImportance"]=regrRM2.feature_importances_
CoeffRM2.sort_values("FeatureImportance", ascending = False)
# Out:
#                            Variable  FeatureImportance
# 228                 rt_Private room           0.424738
# 229                  rt_Shared room           0.081022
# 7                      ng_Manhattan           0.074108
# 4                  availability_365           0.065241
# 2                 reviews_per_month           0.062340
# 5                       name_length           0.062308
# 1                 number_of_reviews           0.046692
# 0                    minimum_nights           0.043951
# 3    calculated_host_listings_count           0.034531
# 222                 nh_Williamsburg           0.012606
# 214           nh_Washington Heights           0.012177
# 102                       nh_Harlem           0.011909
# 70                   nh_East Harlem           0.005106
# 6                       ng_Brooklyn           0.004894
# 111                       nh_Inwood           0.004635
# 99                    nh_Greenpoint           0.003095
# 103               nh_Hell's Kitchen           0.002892
# 22            nh_Bedford-Stuyvesant           0.002260
# 89                   nh_Fort Greene           0.002122
# 209              nh_Upper East Side           0.002042
# 138          nh_Morningside Heights           0.002015
# 83                      nh_Flatbush           0.001975
# 159                   nh_Park Slope           0.001870
# 8                         ng_Queens           0.001786
# 210              nh_Upper West Side           0.001655
# 125             nh_Long Island City           0.001565
# 43                       nh_Chelsea           0.001534
# 50                  nh_Clinton Hill           0.001509
# 37                      nh_Bushwick           0.001502
# 82            nh_Financial District           0.001438
# ..                              ...                ...
# 143                   nh_Mount Eden           0.000000
# 128              nh_Manhattan Beach           0.000000
# 129                  nh_Marble Hill           0.000000
# 140                  nh_Morris Park           0.000000
# 130              nh_Mariners Harbor           0.000000
# 137                   nh_Mill Basin           0.000000
# 132                      nh_Melrose           0.000000
# 156                      nh_Oakwood           0.000000
# 157                    nh_Olinville           0.000000
# 109                     nh_Huguenot           0.000000
# 91                 nh_Fresh Meadows           0.000000
# 74                   nh_Eastchester           0.000000
# 75                      nh_Edenwald           0.000000
# 180                    nh_Rossville           0.000000
# 76                      nh_Edgemere           0.000000
# 78                   nh_Eltingville           0.000000
# 79                  nh_Emerson Hill           0.000000
# 81                     nh_Fieldston           0.000000
# 173                 nh_Richmondtown           0.000000
# 95                  nh_Graniteville           0.000000
# 108                 nh_Howland Hook           0.000000
# 96                    nh_Grant City           0.000000
# 169                nh_Randall Manor           0.000000
# 105                       nh_Hollis           0.000000
# 165                 nh_Prince's Bay           0.000000
# 164                nh_Port Richmond           0.000000
# 106                   nh_Holliswood           0.000000
# 107                 nh_Howard Beach           0.000000
# 161                   nh_Pelham Bay           0.000000
# 115                nh_Jamaica Hills           0.000000
#
# [230 rows x 2 columns]

# %% [markdown]
#  # CrossValidation

# %%
### To find best values for the RF parameters, let us use cross validation
from sklearn.model_selection import RandomizedSearchCV

n_estimators = [int(x) for x in np.linspace(start = 200, stop = 1000, num = 5)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(10, 110, num = 6)]
max_depth.append(None)
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
bootstrap = [True, False]
# Create the random grid
rm_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# %%
print(rm_grid)
# Out:
# {'bootstrap': [True, False], 'min_samples_leaf': [1, 2, 4], 'n_estimators': [200, 400, 600, 800, 1000], 'min_samples_split': [2, 5, 10], 'max_features': ['auto', 'sqrt'], 'max_depth': [10, 30, 50, 70, 90, 110, None]}

# %%
import time

# %%
# Use the random grid to search for best hyperparameters
t1 = time.time()
rf2 = RandomForestRegressor()
# Random search of parameters, using 3 fold cross validation, 
rf2_random = RandomizedSearchCV(estimator = rf2, param_distributions = rm_grid, n_iter = 180, cv = 3, verbose=2, random_state=42, n_jobs = -1)
# Fit the random search model
rf2_random.fit(x_trainL11, y_trainL11)
t2 =time.time()
# Out:
# Fitting 3 folds for each of 180 candidates, totalling 540 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.

# %%
### Time taken
(t2-t1)/60

# %%
### Here we can see Best parameters for the best model
rf2_random.best_params_

# %%
### Final R squared value
rf2_random.score(x_trainL11, y_trainL11)

# %%
### We finally have the least RMSE among all model!
y_predL1= rf2_random.predict(x_testL11)
print(np.sqrt(metrics.mean_squared_error(y_testL11,y_predL1)))

# %%
### Finally lets compare all models
### Including models from my previous project with pyspark
rmsedt = {"Model":["RF1_Sprk","RF2_Sprk","RF3_Sprk","LR","L1","RFR"],"RMSE":[71.55745125705758,65.7207885074504
,62.51297007998151,37.68939882420686,35.12428625156702,34.05098593042094]}
rmsedf = pd.DataFrame(rmsedt)
rsqdt = {"Model":["LR","L1","RFR"],"RSquared":[50.3,56.7,77.8]}
rsqdt = pd.DataFrame(rsqdt)

# %%
sns.catplot(x="Model", y="RMSE", linestyles=["-"],
            kind="point", data=rmsedf);

# %%
sns.catplot(x="Model", y="RSquared", linestyles=["--"], color ="green", kind="point", data=rsqdt);
